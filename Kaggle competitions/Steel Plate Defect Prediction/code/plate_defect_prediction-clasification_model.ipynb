# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from xgboost import XGBClassifier
from functions_predict_plate_defect import *

# %% [markdown]
# # Data

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %% [markdown]
# # XGBoost Grid Search

# %%
outputs=['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

test_prediction = pd.DataFrame({'id': df_test['id']})

for output in outputs:
    test_prediction[output]= xgboost_grid_models(df_train, df_test, output)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Fitting 5 folds for each of 36 candidates, totalling 180 fits

# %%
test_prediction
# Out:
#           id    Pastry  Z_Scratch  K_Scatch    Stains  Dirtiness     Bumps  \
# 0      19219  0.566225   0.000946  0.000872  0.000010   0.003930  0.173823
# 1      19220  0.306243   0.015966  0.003035  0.000018   0.082428  0.171935
# 2      19221  0.001273   0.022533  0.039052  0.000077   0.000926  0.299885
# 3      19222  0.167912   0.000832  0.000257  0.000043   0.003765  0.356277
# 4      19223  0.001507   0.000831  0.000371  0.000241   0.001081  0.601930
# ...      ...       ...        ...       ...       ...        ...       ...
# 12809  32028  0.084327   0.093345  0.000850  0.000010   0.009925  0.212185
# 12810  32029  0.151289   0.003840  0.022847  0.000822   0.066575  0.298947
# 12811  32030  0.000253   0.000740  0.978715  0.000020   0.000108  0.000834
# 12812  32031  0.366695   0.007789  0.016202  0.000015   0.015249  0.178652
# 12813  32032  0.001055   0.003024  0.891911  0.000020   0.000105  0.000718
#
#        Other_Faults
# 0          0.293194
# 1          0.332373
# ...

# %%
test_prediction.to_csv('predict_plate_defect.csv', index=False)
